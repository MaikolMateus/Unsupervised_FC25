# %% [markdown]
# #EDA:Análisis exploratorio de datos EA FC25

# %%
# Importamos las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importamos los datos
datos = pd.read_csv("/content/all_players - all_players.csv")

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17737 entries, 0 to 17736
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           17737 non-null  int64
#  1   Unnamed: 0             17737 non-null  int64
#  2   Rank                   17737 non-null  int64
#  3   Name                   17737 non-null  object
#  4   OVR                    17737 non-null  int64
#  5   PAC                    17737 non-null  int64
#  6   SHO                    17737 non-null  int64
#  7   PAS                    17737 non-null  int64
#  8   DRI                    17737 non-null  int64
#  9   DEF                    17737 non-null  int64
#  10  PHY                    17737 non-null  int64
#  11  Acceleration           17737 non-null  int64
#  12  Sprint Speed           17737 non-null  int64
#  13  Positioning            17737 non-null  int64
#  14  Finishing              17737 non-null  int64
# ...

# %%
datos.describe().T
# Out:
#                       count         mean          std   min     25%     50%  \
# Unnamed: 0.1        17737.0  8868.000000  5120.375198   0.0  4434.0  8868.0
# Unnamed: 0          17737.0  7432.033602  4914.888240   0.0  2858.0  7292.0
# Rank                17737.0  8503.317021  5109.915335   1.0  4260.0  7937.0
# OVR                 17737.0    66.796245     7.030997  47.0    62.0    67.0
# PAC                 17737.0    68.237921    10.587756  29.0    62.0    69.0
# SHO                 17737.0    54.846197    13.858698  20.0    46.0    57.0
# PAS                 17737.0    59.152506     9.826691  25.0    53.0    60.0
# DRI                 17737.0    64.205728     9.359164  29.0    59.0    65.0
# DEF                 17737.0    51.222473    16.477859  15.0    37.0    55.0
# PHY                 17737.0    65.420590     9.468368  32.0    59.0    66.0
# Acceleration        17737.0    64.814343    15.405388  15.0    57.0    68.0
# ...

# %%
# Las 10 ligas con mayor cantidad de jugadores
ligas = datos["League"].value_counts().head(10)

#Grafica
plt.figure(figsize=(6,4))
ligas.plot(kind="bar",color = "teal")
plt.title("Ligas con mayor cantidad de jugadores")
plt.xlabel("Ligas")
plt.ylabel("Cantidad de jugadores")
plt.show()

# %%
#Crearemos un histograma

x = datos["OVR"]
bins_ = np.arange(40,100,1) #bins=Cantidad de ladrillos en ele histograma
bins_

plt.figure(figsize=(6,4))
sns.histplot(x = "OVR",
             data = datos,
             bins = bins_,
             kde =True,
             color = "teal")
plt.title("Distribución del Overall")
plt.grid(True)
plt.show()

# %%
# Gráfica Overall por posición
posiciones = datos.groupby('Position')['OVR'].median().sort_values().index

# %%
import warnings
warnings.filterwarnings('ignore') # Ignorar el decaimiento de los filtros

## Diagrama de cajas (Boxplot)
plt.figure(figsize=(6, 4))
sns.boxplot(x = 'Position',
            y = 'OVR',
            data = datos,
            order = posiciones,
            palette = 'Accent')
plt.xlabel('Posición')
plt.ylabel('Overall')
plt.title('Overall por posición')
plt.show()

# %%
# Matriz de Correlación
corr_matrix = datos[['OVR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].corr()

## Gráfica

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='Reds', linewidths=0.5)
plt.title('Matriz de correlación de los atributos de los jugadores')
plt.show()

# %%
# Mejores 10 jugadores

datos[['Name', 'Position','OVR', 'Team', 'League',
         'Age', 'PAC', 'SHO','DEF','PHY','DRI','PAS']].sort_values(by='OVR', ascending=False).head(10)
# Out:
#                          Name Position  OVR               Team  \
# 0               Kylian Mbappé       ST   91        Real Madrid
# 16161          Aitana Bonmatí       CM   91       FC Barcelona
# 2              Erling Haaland       ST   91    Manchester City
# 1                       Rodri      CDM   91    Manchester City
# 16163  Caroline Graham Hansen       RW   90       FC Barcelona
# 16164                Sam Kerr       ST   90            Chelsea
# 16162         Alexia Putellas       CM   90       FC Barcelona
# 4                    Vini Jr.       LW   90        Real Madrid
# 3             Jude Bellingham      CAM   90        Real Madrid
# 6                  Harry Kane       ST   90  FC Bayern München
#
#                  League  Age  PAC  SHO  DEF  PHY  DRI  PAS
# 0      LALIGA EA SPORTS   25   97   90   36   78   92   80
# 16161            Liga F   26   81   86   77   75   91   86
# 2        Premier League   24   88   92   45   88   81   70
# ...

# %% [markdown]
# #Organizamiento de los datos

# %%
# Volvemos a importar el conjunto de datos
datos.to_csv('all_players - all_players.csv', index=False)

# %%
# Importamos las librerías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
# Publicamos los datos en la web

url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSg9jig5EsHmpD-cE0Rvzst6k84mCdiYfcyEFw9xesoomi_jQ0W1_fF2nfSnFlZonFirLpu-mpNkxT3/pub?output=csv'

data = pd.read_csv(url)
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  Rank             Name  OVR  PAC  SHO  PAS  DRI  \
# 0             0           0     1    Kylian Mbappé   91   97   90   80   92
# 1             1           1     2            Rodri   91   66   80   86   84
# 2             2           2     4   Erling Haaland   91   88   92   70   81
# 3             3           3     5  Jude Bellingham   90   80   87   83   88
# 4             4           4     7         Vini Jr.   90   95   84   81   91
#
#    DEF  ...   Nation            League             Team  \
# 0   36  ...   France  LALIGA EA SPORTS      Real Madrid
# 1   87  ...    Spain    Premier League  Manchester City
# 2   45  ...   Norway    Premier League  Manchester City
# 3   78  ...  England  LALIGA EA SPORTS      Real Madrid
# 4   29  ...   Brazil  LALIGA EA SPORTS      Real Madrid
#
#                                           play style  \
# 0  Quick Step+, Acrobatic, Finesse Shot, Flair, R...
# 1  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...
# ...

# %%
# Reorganizamos las bases de datos

columnas_objetivo = ['Name', 'OVR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Acceleration',
       'Sprint Speed', 'Positioning', 'Finishing', 'Shot Power', 'Long Shots',
       'Volleys', 'Penalties', 'Vision', 'Crossing', 'Free Kick Accuracy',
       'Short Passing', 'Long Passing', 'Curve', 'Dribbling', 'Agility',
       'Balance', 'Reactions', 'Ball Control', 'Composure', 'Interceptions',
       'Heading Accuracy', 'Def Awareness', 'Standing Tackle',
       'Sliding Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression',
       'Weak foot', 'Skill moves', 'Age', 'GK Diving', 'GK Handling',
       'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Preferred foot',]

columnas = data.columns

for col in columnas:
  if col not in columnas_objetivo:
    data.drop(col,axis = 1,inplace = True)
  else:
    data[col] = data[col]

data.head()
# Out:
#               Name  OVR  PAC  SHO  PAS  DRI  DEF  PHY  Acceleration  \
# 0    Kylian Mbappé   91   97   90   80   92   36   78            97
# 1            Rodri   91   66   80   86   84   87   85            65
# 2   Erling Haaland   91   88   92   70   81   45   88            80
# 3  Jude Bellingham   90   80   87   83   88   78   83            81
# 4         Vini Jr.   90   95   84   81   91   29   69            95
#
#    Sprint Speed  ...  Aggression  Weak foot  Skill moves  Preferred foot  Age  \
# 0            97  ...          64          4            5           Right   25
# 1            66  ...          85          4            3           Right   28
# 2            94  ...          88          3            3            Left   24
# 3            80  ...          85          4            4           Right   21
# 4            95  ...          58          4            5           Right   24
#
#    GK Diving  GK Handling  GK Kicking  GK Positioning  GK Reflexes
# ...

# %%
# Verificar datos faltantes
data.isna().sum()
# Out:
# Name                      0
# OVR                       0
# PAC                       0
# SHO                       0
# PAS                       0
# DRI                       0
# DEF                       0
# PHY                       0
# Acceleration              0
# Sprint Speed              0
# Positioning               0
# Finishing                 0
# Shot Power                0
# Long Shots                0
# Volleys                   0
# Penalties                 0
# Vision                    0
# Crossing                  0
# Free Kick Accuracy        0
# Short Passing             0
# Long Passing              0
# Curve                     0
# Dribbling                 0
# Agility                   0
# Balance                   0
# Reactions                 0
# Ball Control              0
# Composure                 0
# Interceptions             0
# Heading Accuracy          0
# Def Awareness             0
# Standing Tackle           0
# Sliding Tackle            0
# ...

# %%
#Imputar datos faltantes para las categorías de GK cambiando NaN por 0

gk_columns = ['GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes']
data[gk_columns] = data[gk_columns].fillna(0)

# %%
# Extraemos los datos

X = data.iloc[:,1:].values

# %%
X
# Out:
# array([[91, 97, 90, ..., 0.0, 0.0, 0.0],
#        [91, 66, 80, ..., 0.0, 0.0, 0.0],
#        [91, 88, 92, ..., 0.0, 0.0, 0.0],
#        ...,
#        [53, 60, 58, ..., 0.0, 0.0, 0.0],
#        [53, 61, 52, ..., 0.0, 0.0, 0.0],
#        [53, 60, 49, ..., 0.0, 0.0, 0.0]], dtype=object)

# %%
X.shape
# Out:
# (17737, 45)

# %%
data.iloc[:,-7]
# Out:
# 0        Right
# 1        Right
# 2         Left
# 3        Right
# 4        Right
#          ...
# 17732    Right
# 17733    Right
# 17734    Right
# 17735     Left
# 17736     Left
# Name: Preferred foot, Length: 17737, dtype: object

# %%
# Codificar el pie preferido como variable numérica
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

X[:, -7] = le.fit_transform(X[:, -7])

# Verificamos
X[:, -7]
# Out:
# array([1, 1, 0, ..., 1, 0, 0], dtype=object)

# %%
# Data Frame a valores numéricos
df = pd.DataFrame(X)
for col in df.columns:
    # Convertir a numérico, forzando errores a NaN
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
X = df.values
X
# Out:
# array([[91., 97., 90., ...,  0.,  0.,  0.],
#        [91., 66., 80., ...,  0.,  0.,  0.],
#        [91., 88., 92., ...,  0.,  0.,  0.],
#        ...,
#        [53., 60., 58., ...,  0.,  0.,  0.],
#        [53., 61., 52., ...,  0.,  0.,  0.],
#        [53., 60., 49., ...,  0.,  0.,  0.]])

# %%
# Empezamos a definir las librerías para el método con sklearn
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer.fit(X)
X = imputer.transform(X)
X
# Out:
# array([[91., 97., 90., ...,  0.,  0.,  0.],
#        [91., 66., 80., ...,  0.,  0.,  0.],
#        [91., 88., 92., ...,  0.,  0.,  0.],
#        ...,
#        [53., 60., 58., ...,  0.,  0.,  0.],
#        [53., 61., 52., ...,  0.,  0.,  0.],
#        [53., 60., 49., ...,  0.,  0.,  0.]])

# %% [markdown]
# # Montaje de Algoritmo de Clasificación K-means

# %% [markdown]
# ##PCA

# %%
# Definimos las librerías
from sklearn.decomposition import PCA

# Crear un objeto PCA y ajustar los datos de las tres principales componentes
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X)

# %%
# Verificamos la varianza de los datos
varianza = pca.explained_variance_ratio_
print(sum(varianza))
# Out:
# 0.8397093998660171

# %%
# método del codo
from sklearn.cluster import KMeans
## Inicializo donde almaceno el WCCS(k)
WCSS = []

for k in range(1,11):
  kpp = KMeans(n_clusters= k,
               init = 'k-means++',
               random_state=42, n_init = 'auto')
  kpp.fit(X)
  WCSS.append(kpp.inertia_)

plt.figure()
plt.plot(range(1,11), WCSS, 'o--', color = 'blue')
plt.title('Método del Codo-Kmeans K++')
plt.xlabel('k')
plt.ylabel('WCSS')
plt.grid(True)
plt.grid(linestyle = '-')
plt.show()

# Según la interpretación de los nodos, encontramos el valor de cluster optimo en x=4

# %% [markdown]
# ## Usando la librería Sklearn y K++

# %%
# Definimos la librería
from sklearn.cluster import KMeans

# Definimos el algoritmo
kmeans_mas = KMeans(n_clusters=4, random_state=42, init='k-means++')
clusters_kmeans_mas = kmeans_mas.fit_predict(X) # Organizar y asociando los datos en 4 grupos.

# %%
# Definimos los centroides
centroides_kmeans_mas = kmeans_mas.cluster_centers_
centroides_kmeans = pca.transform(centroides_kmeans_mas)
centroides_kmeans
# Out:
# array([[-18.92261285, -51.15290841, -19.91868549],
#        [207.53624617, -14.95768587,  30.71744999],
#        [  1.7006178 ,  51.9204732 , -17.30972911],
#        [-57.46487019,   5.86526214,  22.12620196]])

# %%
# Definimos la función de gráfica de clusters y centroides 2D

def graficar_clusters_PCA2D(clusters, metodo, centroids):
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1],
                    hue=clusters, palette='deep',
                    alpha=0.6, s = 100)
    plt.scatter(centroids[:,0], centroids[:,1], c= 'black', s = 100, label = 'centroides')
    plt.title(f'Visualización 2D de la Clusterización (PCA) {metodo}', fontsize=16)
    plt.xlabel('Componente Principal 1')
    plt.ylabel('Componente Principal 2')
    plt.grid(True)
    plt.grid(linestyle = '-', alpha  = 0.5)
    plt.legend(title='Cluster')
    plt.show()

# %%
# Definimos la función de gráfica de clusters y centroides 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns

def graficar_clusters_PCA3D(cluster,metodo):
    #Crear el grafico 3D
    fig = plt.figure(figsize=(15, 8))
    ax = fig.add_subplot(111, projection='3d')

   #Graficar los puntos con borde blanco
    scatter = ax.scatter(X_pca[:, 0],X_pca[:, 1],X_pca[:, 2],
                         c=cluster,cmap='viridis', s=100,
                        edgecolor ='white',alpha = 0.6)
    #Etiquetas de los ejes y titulo
    ax.set_title(f'Visualización 3D de la Clusterización (PCA) (metodo)', fontsize=16)
    ax.set_xlabel('Componente Principal 1')
    ax.set_ylabel('Componente Principal 2')
    ax.set_zlabel('Componente Principal 3')

    #Añadir leyenda
    legend1 = ax.legend(*scatter.legend_elements(), title = "Clusters")
    ax.add_artist(legend1)

    #Mostrar grafico
    plt.show()

# %% [markdown]
# ## Gráficas

# %%
k_means_sklearn_2D = graficar_clusters_PCA2D(clusters_kmeans_mas, 'K-means-Sklearn-Gráfica 2D-K++', centroides_kmeans)

# %%
k_means_sklearn_3D = graficar_clusters_PCA3D(clusters_kmeans_mas, 'K-means-Sklearn-Gráfica 3D-K++')

# %%
# Guardar base de datos para compañero
X = pd.DataFrame(X)
# Exportar conjunto de datos
X.to_csv('datos_ultimos.csv', index=False)

# %% [markdown]
# ##Descripción del conjunto de datos (2 renglones)
# - Se hace un EDA
# Descripción del workflow:
# Con cuantas variables se trabaja (cuantas se escogen), la escala.
# - Se imputan los datos faltantes, se codifica la variable pie preferido a una variabale binaria.
# - Implementación del k-means usando librerías
# - Implementación manual del algoritmo usando 3 tipos de distancias diferentes (eu, mh, l1)
# - Descripción del algoritmo (como el video). (ejercicio de clasificación, no supervisado
